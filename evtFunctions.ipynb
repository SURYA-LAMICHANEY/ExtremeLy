# %%
#Importing required libraries
import pandas as pd
from ExtremeLy import extremely as ely

# %%
pip install ExtremeLy==2.0.0
# Out:
# Collecting ExtremeLy==2.0.0
#   Downloading ExtremeLy-2.0.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: evt in /home/msc2/anaconda3/lib/python3.9/site-packages (from ExtremeLy==2.0.0) (0.0.2)
# Requirement already satisfied: lmoments3 in /home/msc2/anaconda3/lib/python3.9/site-packages (from ExtremeLy==2.0.0) (1.0.4+9.g7e19f97)
# Requirement already satisfied: matplotlib>=3.4 in /home/msc2/anaconda3/lib/python3.9/site-packages (from evt->ExtremeLy==2.0.0) (3.4.3)
# Requirement already satisfied: scipy>=1.6 in /home/msc2/anaconda3/lib/python3.9/site-packages (from evt->ExtremeLy==2.0.0) (1.8.0)
# Requirement already satisfied: numpy>=1.20 in /home/msc2/anaconda3/lib/python3.9/site-packages (from evt->ExtremeLy==2.0.0) (1.20.3)
# Requirement already satisfied: pandas>=1.2 in /home/msc2/anaconda3/lib/python3.9/site-packages (from evt->ExtremeLy==2.0.0) (1.3.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/msc2/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->evt->ExtremeLy==2.0.0) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/msc2/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->evt->ExtremeLy==2.0.0) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/msc2/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->evt->ExtremeLy==2.0.0) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/msc2/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->evt->ExtremeLy==2.0.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/msc2/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.4->evt->ExtremeLy==2.0.0) (3.0.4)
# Requirement already satisfied: six in /home/msc2/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.4->evt->ExtremeLy==2.0.0) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /home/msc2/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->evt->ExtremeLy==2.0.0) (2021.3)
# Installing collected packages: ExtremeLy
#   Attempting uninstall: ExtremeLy
#     Found existing installation: ExtremeLy 1.3.3
#     Uninstalling ExtremeLy-1.3.3:
#       Successfully uninstalled ExtremeLy-1.3.3
# Successfully installed ExtremeLy-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Hiding all the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the Danish Univariate dataset.
data = pd.read_csv("/home/msc2/Desktop/Project/Learning Concepts/danishuni.csv",index_col=0)
data.head()
# Out:
#          Date      Loss
# 1  1980-01-03  1.683748
# 2  1980-01-04  2.093704
# 3  1980-01-05  1.732581
# 4  1980-01-07  1.779754
# 5  1980-01-07  4.612006

# %%
#Basic info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2167 entries, 1 to 2167
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2167 non-null   object
#  1   Loss    2167 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 50.8+ KB

# %%
#5 point summary of the data
data.describe()
# Out:
#               Loss
# count  2167.000000
# mean      3.385088
# std       8.507452
# min       1.000000
# 25%       1.321119
# 50%       1.778154
# 75%       2.967023
# max     263.250366

# %%
#Calling the getBM method of ExtremeLy. Note: all th functions of ExtremeLy take input of dataframe having first
#column as Date and second column as the Loss column of our interest.
maxima=ely.getBM(sample=data,period="Y") # Here Y means Yearly, we can pass M for monthly, W for weekly and D for daily.
maxima
# Out:
#          Date        Loss
# 0  1980-12-31  263.250366
# 1  1981-12-31   56.225426
# 2  1982-12-31   65.707491
# 3  1983-12-30   13.348165
# 4  1984-12-31   19.162304
# 5  1985-12-29   57.410636
# 6  1986-12-30   29.026037
# 7  1987-12-31   32.467532
# 8  1988-12-26   47.019521
# 9  1989-12-31  152.413209
# 10 1990-12-31  144.657591

# %%
#Fitting the GEV distribution with maxima values. Here, default fit_method is MLE and default Confidence interval method is delta.
fit=ely.gevfit(sample=maxima,fit_method="mle",ci=0,ci_method="delta")

# %%
#Getting estimated distribution parameters for GEV fit.
params=ely.gevparams(model=fit)
params
# Out:
# OrderedDict([('shape', -0.6384049125307144),
#              ('location', 37.79353853187126),
#              ('scale', 28.93607752286071)])

# %%
#Summarizing the GEV model with various plots like QQplot, PPplot, Return Level Plot and Data Probability density plot
ely.gevsummary(model=fit)

# %%
#Calculating value-at-Risk 
var=ely.gevVaR(sample=maxima)
print("Value-at-Risk at 99% confidence interval is",round(var,2),"million Danish Krones.")
# Out:
# Value-at-Risk at 99% confidence interval is 847.06 million Danish Krones.

# %%
#Mean Residual Life plot for finding appropriate threshold value for Peak-Over-Threshold method.
ely.MRL(sample=data,alpha=0.05)

# %%
#Getting large claims using POT method using threshold value as 30.
ely.getPOT(sample=data,threshold=30)
# Out:
#             Date        Loss
# index
# 82    1980-07-15  263.250366
# 178   1981-02-10   34.141547
# 232   1981-05-29   56.225426
# 330   1981-12-21   50.065531
# 478   1982-10-24   65.707491
# 887   1985-03-04   46.500000
# 972   1985-08-23   57.410636
# 1388  1987-06-05   32.467532
# 1549  1988-03-25   38.154392
# 1641  1988-08-12   47.019521
# 1710  1988-12-17   31.055901
# 1740  1989-02-14   42.091448
# 1856  1989-08-04  152.413209
# 1909  1989-10-22   32.387807
# 2121  1990-10-08  144.657591

# %%
#Fitting GPD with large claims obtained using POT method.
gpdfit=ely.gpdfit(sample=data,threshold=30)

# %%
#Getting estimated distribution parameters for GPD fit.
ely.gpdparams(fit=gpdfit)
# Out:
# Shape: 0.6586260117024005
# Scale: 19.267021192664032

# %%
#Data Probability Density Function plot.
ely.gpdpdf(sample=data,threshold=30,bin_method="sturges",alpha=0.05)

# %%
#Cumulative Density Function plot.
ely.gpdcdf(sample=data,threshold=10,alpha=0.05)

# %%
#Quantile-Quantile plot.
ely.gpdqqplot(gpdfit[5])

# %%
#Probability-Probaility plot.
ely.gpdppplot(sample=data,threshold=10,alpha=0.5)

# %%
#Survival Function
ely.survival_function(sample=data,threshold=10,alpha=0.05)
